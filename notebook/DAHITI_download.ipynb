# %%
# %load download_water_level_altimetry.py
#!/usr/bin/python3
""" Version: 1.11 """
""" Author: Christian Schwatke <christian.schwatke@tum.de>"""
""" Last change: 2022-01-10 """
# Out:
# ' Last change: 2022-01-10 '

# %%
import os
import sys
import json
import pprint
import requests
import datetime

# %%
# Download path were all water level time series will be stored
download_path = 'E:/casadje/jrcbox/datasets/lakes/DAHITI/'
if not os.path.isdir(download_path):
    os.mkdir(download_path)

# %%
args = {}
# User configuration
# IMPORTANT! Your DAHITI user account must be assigned to the 'GlobalCDA' group in order 
# to access globalcda parameters such as arc-id, poly-id, basin-id
args['username'] = 'casadoje'
args['password'] = '#Urr13()u#'

# General search options
#args['basin'] = 'Amazon' # These basins differ from globalcda basins
#args['continent'] = 'Asia'
#args['country'] = 'de'
#args['min_lon'] = 0
#args['max_lon'] = 10
#args['min_lat'] = 0
#args['max_lat'] = 10
#args['software'] = '3.1'

# %%
# Globalcda search options
# args['basin_id'] = '7309' # Mississippi
#args['basin_id'] = '9232' # Amazon
# args['basin_id'] = '9719' # Congo
# args['basin_id'] = '7756' # Ganges
args['poly_id'] = '39012' #'527'
# args['arc_id'] = '29046'

# %%
url = 'https://dahiti.dgfi.tum.de/api/v1/'

# send request as method POST
args['action'] = 'list-targets'
response = requests.post(url, data=args)
if response.status_code == 200:
    # convert json string in python list
    data = json.loads(response.text)
    print ('Dataset(s) found:',len(data))
    i = 0
    for record in data:
        print ('Downloading ... ', record['id'], '->', record['target_name'].encode("utf8"), '(' + os.path.abspath(download_path + '/' + str(record['id']) + '.txt') + ')')

        # download water level time series
        args['action'] = 'download'
        args['dahiti_id'] = record['id']

        response_download = requests.post(url, data=args)
        if response_download.status_code == 200:
            # convert json string in python list
            data = json.loads(response_download.text)
            output = open(download_path + '/' + str(record['id']) + '.txt', 'w')
            output.write('# DAHITI-ID       : ' + str(record['id']) + '\n')
            output.write('# Target name     : ' + record['target_name'].encode("utf8").decode() + '\n')
            if record['location'] == None:
                output.write('# Location        : ' + str(record['location']) + '\n')
            else:
                output.write('# Location        : ' + str(record['location'].encode("utf8").decode()) + '\n')
            output.write('# Continent       : '+str(record['continent'])+'\n')
            output.write('# Country         : '+str(record['country'])+'\n')
            output.write('# Longitude       : '+str(record['longitude'])+'\n')
            output.write('# Latitude        : '+str(record['latitude'])+'\n')
            output.write('# Points          : '+str(len(data))+'\n')
            output.write('# Software        : '+str(record['water_level']['software'])+'\n')
            output.write('# Download        : '+str(datetime.datetime.now())[0:19]+'\n')
            output.write('# Last-Update     : '+str(record['water_level']['last_update'])+'\n')			
            output.write('# ----------------------------------------\n')
            output.write('# column 1        : date [yyyy-mm-dd]\n')
            output.write('# column 2        : normal heights w.r.t. geoid model [m]\n')
            output.write('# column 3        : error [m] (Kalman Filter, formal errors)\n')
            output.write('# column 4        : dataset (OP:operational, RT:real-time, CB:operational+real-time)\n')
            output.write('# ----------------------------------------\n')
            for entry in data['target']['data']:
                output.write(str(entry['date'])+' '+str(entry['height'])+' '+str(entry['error'])+' '+str(entry['data_type'])+'\n')
            output.close()
        elif response_download.status_code == 403:
            print ('Status-Code:', response_download.status_code, '- Permission denied!')
        else:
            print ('Status-Code:', response_download.status_code)

elif response.status_code == 403:
    print ('Status-Code:', response.status_code, '- Permission denied!')
else:
    print ('Status-Code:', response.status_code)
# Out:
# Dataset(s) found: 9928
# Downloading ...  16165 -> b'Aamzon, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\
, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\18220.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  1859 -> b'Apaporis, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\1859.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  1939 -> b'Apaporis, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\1939.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  12619 -> b'Apaporis, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\12619.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  12816 -> b'Apaporis, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\12816.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  12896 -> b'Apaporis, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\12896.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  14217 -> b'Apaporis, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\14217.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  17864 -> b'Apaporis, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\17864.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  18147 -> b'Apaporis, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\18147.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  19075 -> b'Apaporis, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\19075.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  20240 -> b'Apaporis, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\20240.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  20241 -> b'Apaporis, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\20241.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  20574 -> b'Apaporis, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\20574.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  40009 -> b'Apaporis, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\40009.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  28462 -> b'Apere, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\28462.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  18172 -> b'Apiac\xc3\xa1s, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\18172.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  18173 -> b'Apiac\xc3\xa1s, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\18173.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  11657 -> b'Apoporis, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\11657.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  6185 -> b'Apoquitaua, Lake' (E:\casadje\jrcbox\datasets\lakes\DAHITI\6185.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  17905 -> b'Apoquitaua, Lake' (E:\casadje\jrcbox\datasets\lakes\DAHITI\17905.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  6184 -> b'Apoquitaua, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\6184.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  4176 -> b'Apua\xc3\xba, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\4176.txt)
# Downloading ...  1252 -> b'Apure, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\1252.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  16492 -> b'Apure, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\16492.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  18767 -> b'Apure, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\18767.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  19781 -> b'Apure, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\19781.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  23470 -> b'Apure, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\23470.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  1874 -> b'Apurito, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\1874.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  17934 -> b'Apxapa, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\17934.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  11004 -> b'Aqqikkol, Lake' (E:\casadje\jrcbox\datasets\lakes\DAHITI\11004.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  13152 -> b'Aquilla, Lake' (E:\casadje\jrcbox\datasets\lakes\DAHITI\13152.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  32334 -> b'Arabela, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\32334.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  32338 -> b'Arabela, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\32338.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  32339 -> b'Arabela, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\32339.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  3070 -> b'Araca, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\3070.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  3071 -> b'Araca, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\3071.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  14931 -> b'Arac\xc3\xa1, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\14931.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  20247 -> b'Arac\xc3\xa1, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\20247.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  20248 -> b'Arac\xc3\xa1, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\20248.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  10297 -> b'Arag\xc3\xb3n, Lake' (E:\casadje\jrcbox\datasets\lakes\DAHITI\10297.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  1002 -> b'Araguaia, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\1002.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  1025 -> b'Araguaia, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\1025.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  1026 -> b'Araguaia, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\1026.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  1027 -> b'Araguaia, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\1027.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  1028 -> b'Araguaia, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\1028.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  1029 -> b'Araguaia, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\1029.txt)
# Downloading ...  1030 -> b'Araguaia, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\1030.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  1031 -> b'Araguaia, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\1031.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  1058 -> b'Araguaia, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\1058.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  1059 -> b'Araguaia, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\1059.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  1060 -> b'Araguaia, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\1060.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  1061 -> b'Araguaia, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\1061.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  1062 -> b'Araguaia, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\1062.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  1063 -> b'Araguaia, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\1063.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  1064 -> b'Araguaia, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\1064.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  7284 -> b'Araguaia, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\7284.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  9247 -> b'Araguaia, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\9247.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  14550 -> b'Araguaia, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\14550.txt)
# Status-Code: 403 - Permission denied!
# Downloading ...  15112 -> b'Araguaia, River' (E:\casadje\jrcbox\datasets\lakes\DAHITI\15112.txt)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [6], line 18
#      15 args['action'] = 'download'
#      16 args['dahiti_id'] = record['id']
# ---> 18 response_download = requests.post(url, data=args)
#      19 if response_download.status_code == 200:
#      20     # convert json string in python list
#      21     data = json.loads(response_download.text)
#
# File C:\DEV\Anaconda3\envs\xr\lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File C:\DEV\Anaconda3\envs\xr\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File C:\DEV\Anaconda3\envs\xr\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File C:\DEV\Anaconda3\envs\xr\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File C:\DEV\Anaconda3\envs\xr\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File C:\DEV\Anaconda3\envs\xr\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File C:\DEV\Anaconda3\envs\xr\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File C:\DEV\Anaconda3\envs\xr\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File C:\DEV\Anaconda3\envs\xr\lib\http\client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File C:\DEV\Anaconda3\envs\xr\lib\http\client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File C:\DEV\Anaconda3\envs\xr\lib\http\client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File C:\DEV\Anaconda3\envs\xr\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File C:\DEV\Anaconda3\envs\xr\lib\ssl.py:1242, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238     if flags != 0:
#    1239         raise ValueError(
#    1240           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241           self.__class__)
# -> 1242     return self.read(nbytes, buffer)
#    1243 else:
#    1244     return super().recv_into(buffer, nbytes, flags)
#
# File C:\DEV\Anaconda3\envs\xr\lib\ssl.py:1100, in SSLSocket.read(self, len, buffer)
#    1098 try:
#    1099     if buffer is not None:
# -> 1100         return self._sslobj.read(len, buffer)
#    1101     else:
#    1102         return self._sslobj.read(len)
#
# KeyboardInterrupt:
