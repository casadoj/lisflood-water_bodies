# %% [markdown]
# # Bivariate calibration
# ***
#
# **Autor:** Chus Casado<br>
# **Date:** 08-11-2023<br>
#
# **To do:**<br>
# * [ ] Clean observed time series
#
# **Questions:**<br>
# * [x] What's the relation between likelihood and KGE? Answer:
# $$Likelihood = 1 - KGE$$
# * [ ] Fit the $Q_{min}$ based on the inflow data. Hot to fit a GEV to minima.
# * [ ] Analyse the optimized parameters. Try to find a pattern related to reservoir use, size, catchment area...
#
# **Ideas:**<br>
# * SpotPy can not apply any optimization algorithm to a bivariable calibration. Instead, it includes different sampling methods (not optimization) such as Latin Hypercube and Monte Carlo. These two methods are good to explore the parameter space, but will not provide the global optimal parameters. In this notebook I compute the Pareto front of the outflow and storage KGE, and select as the optimal parameter set the one that is closer to the (1, 1) point. That means that I give equal importance to outflow and storage, and that the best parameter set is a Euclidean distance from the optimum value of (1, 1). If that approach is good, I could use an optimazation algorithm like SCE-UA to find the global optimum, provided that the target metric is the composition of the KGE values for storage and outflow:
# $$OF = \sqrt{{(1 - KGE_{outflow})^2 + (1 - KGE_{storage} )^2}}$$

# %%
import os
os.environ['USE_PYGEOS'] = '0'
import numpy as np
import pandas as pd
import xarray as xr
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
import spotpy
from spotpy.objectivefunctions import kge
import yaml
from pathlib import Path
from tqdm.notebook import tqdm
import glob
# import cartopy.crs as ccrs
# import cartopy.feature as cf

# %%
from calibration.bivariate_lisflood import bivariate_6pars
from reservoirs import Lisflood
from metrics import KGEmod, pareto_front
from plots import plot_iterations

# %% [markdown]
# ## Configuration

# %%
path_datasets = Path('Z:/nahaUsers/casadje/datasets/')

# results will be saved in this path
path_out = Path('../results/reservoirs/LISFLOOD/calibration/MC/6parameters/')
path_out.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Calibration

# %%
# # sequential mode
parallel = 'seq'

# SCEUA parameters
max_iter = 600
# complexes = 4
train_size = .7

# %% [markdown]
# ## Data

# %% [markdown]
# ### GloFAS

# %% [markdown]
# #### Reservoirs

# %%
# load shapefile of GloFAS reservoirs
reservoirs = gpd.read_file('../GIS/reservoirs_analysis_US.shp')
reservoirs.set_index('ResID', drop=True, inplace=True)

print(f'{reservoirs.shape[0]} reservoirs in the shape file')
# Out:
# 94 reservoirs in the shape file

# %% [markdown]
# #### Time series

# %%
# read GloFAS time series
path = Path('../data/reservoirs/GloFAS/long_run')
glofas_ts = {}
for file in tqdm(glob.glob(f'{path}/*.csv')):
    id = int(file.split('\\')[-1].split('.')[0].lstrip('0'))
    if id not in reservoirs.index:
        continue
    glofas_ts[id] = pd.read_csv(file, parse_dates=True, dayfirst=False, index_col='date')
    
print(f'{len(glofas_ts)} reservoirs in the GloFAS time series')

# convert storage time series into volume
for id, df in glofas_ts.items():
    df.storage *= reservoirs.loc[id, 'CAP'] * 1e6

# period of GloFAS simulation
start, end = glofas_ts[id].first_valid_index(), glofas_ts[id].last_valid_index()
# Out:
#   0%|          | 0/143 [00:00<?, ?it/s]
# 94 reservoirs in the GloFAS time series

# %% [markdown]
# ### ResOpsUS
# #### Time series

# %%
path_ResOps = Path(path_datasets / 'reservoirs' / 'ResOpsUS')

resops_ts = {}
for glofas_id in tqdm(reservoirs.index):
    # load timeseries
    grand_id = reservoirs.loc[glofas_id, 'GRAND_ID']
    series_id = pd.read_csv(path_ResOps / 'time_series_all' / f'ResOpsUS_{grand_id}.csv', parse_dates=True, index_col='date')
    # remove empty time series
    series_id = series_id.loc[start:end]#.dropna(axis=1, how='all')
    # remove duplicated index
    series_id = series_id[~series_id.index.duplicated(keep='first')]
    # save in dictionary
    resops_ts[glofas_id] = series_id

print(f'{len(resops_ts)} reservoirs in the ResOpsUS time series')
    
# convert storage from hm3 to m3
for id, df in resops_ts.items():
    df.storage *= 1e6
# Out:
#   0%|          | 0/94 [00:00<?, ?it/s]
# 94 reservoirs in the ResOpsUS time series

# %% [markdown]
# ## Markov chain sampling

# %%
# GloFAS reservoir
for ResID in tqdm(reservoirs.index):
    
    # file where the calibration results will be saved
    dbname = f'{path_out}/{ResID:03}_samples'
    if os.path.isfile(dbname + '.csv'):
        print(f'The file {dbname}.csv already exists.')
        continue
            
    ## TIME SERIES
    try:
        # observed time series
        obs = resops_ts[ResID][['storage', 'inflow', 'outflow']].copy()
        obs[obs < 0] = np.nan

        # define calibration period
        if obs.outflow.isnull().all():
            print(f'Reservoir {ResID} is missing outflow records')
            # continue
        elif obs.storage.isnull().all():
            print(f'Reservoir {ResID} is missing storage records')
            # continue
        else:
            start_obs = max([obs[var].first_valid_index() for var in ['storage', 'outflow']])
            end_obs = min([obs[var].last_valid_index() for var in ['storage', 'outflow']])
            cal_days = timedelta(days=np.floor((end_obs - start_obs).days * train_size))
            start_cal = end_obs - cal_days

        # define train and test time series
        x_train = glofas_ts[ResID].inflow[start_cal:end_obs]
        y_train = obs.loc[start_cal:end_obs, ['storage', 'outflow']]
        x_test = glofas_ts[ResID].inflow[start:start_cal]
        y_test = obs.loc[start_obs:start_cal, ['storage', 'outflow']]
        
    except:
        print(f'ERROR. The time series of reservoir {ResID} could not be set up')
        continue
        
    ## SET UP SPOTPY
    try:
        # extract GloFAS reservoir parameters
        Vc, Vtot, Qmin = reservoirs.loc[ResID, ['clim', 'CAP', 'minq']]
        Vtot *= 1e6
        Vc *= Vtot

        # initialize the calibration setup of the LISFLOOD reservoir routine
        setup = bivariate_6pars(x_train, y_train.storage, y_train.outflow,
                                Vc, Vtot, Qmin,
                                KGEmod)

        # define the sampling method
        mc = spotpy.algorithms.mc(setup, parallel=parallel, dbname=dbname, dbformat='csv', save_sim=False)
    except:
        print(f'ERROR. The SpotPY set up of reservoir {ResID} could not be done')

    ## LAUNCH SAMPLING
    try:
        # start the sampler
        mc.sample(max_iter)
    except:
        print(f'ERROR. While sampling the reservoir {ResID}')
        continue
        
    ### ANALYSE RESULTS
    
    try:
        # read CSV of results
        results = pd.read_csv(f'{dbname}.csv')
        results.index.name = 'iteration'
        parcols = [col for col in results.columns if col.startswith('par')]
        
        # plot pairplot of the combined likelihood
        results['likelihood'] = results[['like1', 'like2']].pow(2).sum(axis=1).pow(.5)
        sns.pairplot(results, vars=parcols, corner=True, hue='likelihood', palette='Spectral_r', plot_kws={'s': 12})
        plt.savefig(path_out / f'{ResID:03}_pairplot.jpg', dpi=300, bbox_inches='tight');
        
    except:
        print(f'ERROR while reading results form reservoir {ResID}')
        continue
        
    try:
        # compute the Pareto front and the best iteration
        front = pareto_front(results.like1, results.like2)
        best_iter = front.pow(2).sum(axis=1).pow(.5).idxmin()
        plot_iterations(results, front, best_iter, save=path_out / f'{ResID:03}_pareto_front.jpg')

        # select optimal parameters
        best_iter = results.like1.idxmin()
        parvalues = {col[3:]: float(results.loc[best_iter, col]) for col in parcols}

        # export optimal parameters
        with open(f'{path_out}/{ResID:03}_optimal_parameters.yml', 'w') as file:
            yaml.dump(parvalues, file)
    except:
        print(f'ERROR while searching for optimal parameters in reservoir {ResID}')
        continue
        
    try:
        # # declare the reservoir with the optimal parameters
        # Vn, Vf = [parvalues[var] * Vtot for var in ['FFn', 'FFf']]
        # Vn_adj = Vn + parvalues['alpha'] * (Vf - Vn)
        # Qn, Qf = [setup.inflow.quantile(parvalues[var]) for var in ['QQn', 'QQf']]
        # k = parvalues['k']
        # res = Lisflood(Vc, Vn, Vn_adj, Vf, Vtot, Qmin, Qn, Qf)
        
        # declare the reservoir with the optimal parameters
        Vf = parvalues['FFf'] * Vtot
        Vn = parvalues['alpha'] * Vf
        Vn_adj = Vn + parvalues['beta'] * (Vf - Vn)
        Qf = setup.inflow.quantile(parvalues['QQf'])
        Qn = parvalues['gamma'] * Qf
        k = parvalues['k']
        res = Lisflood(Vc, Vn, Vn_adj, Vf, Vtot, Qmin, Qn, Qf)

        # define time series
        start_obs = max([resops_ts[ResID][var].first_valid_index() for var in ['storage', 'outflow']])
        x = glofas_ts[ResID][start_obs:]
        y = resops_ts[ResID][start_obs:]

        # simulate the whole period and analyse
        sim = res.simulate(x.inflow, y.storage[start_obs], k=k)
        res.scatter(sim, y, norm=False, title=ResID, save=path_out / f'{ResID:03}_scatter.jpg')
        res.lineplot({'GloFAS': x, 'cal': sim}, y, save=path_out / f'{ResID:03}_lineplot.jpg')

    except:
        print(f'ERROR while simulating with optimal parameters in reservoir {ResID}')
# Out:
#   0%|          | 0/94 [00:00<?, ?it/s]
# Initializing the  Monte Carlo (MC) sampler  with  600  repetitions
# Starting the MC algorithm with 600 repetitions...
# Initialize database...
# ['csv', 'hdf5', 'ram', 'sql', 'custom', 'noData']
# * Database file '..\results\reservoirs\LISFLOOD\calibration\MC\6_parameters/007_samples.csv' created.
# 3 of 600, min objf=0.754684, max objf=0.889661, time remaining: 00:05:08
# 6 of 600, min objf=0.731616, max objf=0.889661, time remaining: 00:06:08
# 9 of 600, min objf=0.731616, max objf=0.953465, time remaining: 00:06:31
# 12 of 600, min objf=0.731616, max objf=0.963909, time remaining: 00:06:36
# 15 of 600, min objf=0.731616, max objf=0.963909, time remaining: 00:06:41
# 18 of 600, min objf=0.731616, max objf=0.963909, time remaining: 00:06:43
# 21 of 600, min objf=0.731616, max objf=0.963909, time remaining: 00:06:45
# 24 of 600, min objf=0.731616, max objf=0.963909, time remaining: 00:06:48
# 27 of 600, min objf=0.731616, max objf=0.963909, time remaining: 00:06:49
# 30 of 600, min objf=0.731557, max objf=0.963909, time remaining: 00:06:56
# 33 of 600, min objf=0.731557, max objf=0.963909, time remaining: 00:06:56
# 36 of 600, min objf=0.731557, max objf=0.963909, time remaining: 00:06:56
# 39 of 600, min objf=0.731557, max objf=0.963909, time remaining: 00:06:51
# 42 of 600, min objf=0.731557, max objf=0.963909, time remaining: 00:06:50
# 45 of 600, min objf=0.731557, max objf=0.963909, time remaining: 00:06:48
# 48 of 600, min objf=0.730963, max objf=0.963909, time remaining: 00:06:47
# 51 of 600, min objf=0.730963, max objf=0.963909, time remaining: 00:06:45
# 54 of 600, min objf=0.730963, max objf=0.963909, time remaining: 00:06:42
# 57 of 600, min objf=0.730963, max objf=0.963909, time remaining: 00:06:39
# 60 of 600, min objf=0.730963, max objf=0.963909, time remaining: 00:06:36
# 63 of 600, min objf=0.655714, max objf=0.963909, time remaining: 00:06:33
# 66 of 600, min objf=0.655714, max objf=0.963909, time remaining: 00:06:31
# 69 of 600, min objf=0.655714, max objf=0.963909, time remaining: 00:06:29
# 72 of 600, min objf=0.655714, max objf=0.963909, time remaining: 00:06:29
# 75 of 600, min objf=0.655714, max objf=0.963909, time remaining: 00:06:27
# 78 of 600, min objf=0.655714, max objf=0.963909, time remaining: 00:06:25
# 81 of 600, min objf=0.655714, max objf=0.963909, time remaining: 00:06:22
# 84 of 600, min objf=0.655714, max objf=0.963909, time remaining: 00:06:20
# 87 of 600, min objf=0.655714, max objf=0.963909, time remaining: 00:06:17
# 90 of 600, min objf=0.655714, max objf=0.963909, time remaining: 00:06:15
# 93 of 600, min objf=0.655714, max objf=0.963909, time remaining: 00:06:12
# 96 of 600, min objf=0.655714, max objf=0.963909, time remaining: 00:06:10
# 99 of 600, min objf=0.655714, max objf=0.963909, time remaining: 00:06:08
# 102 of 600, min objf=0.655714, max objf=0.963909, time remaining: 00:06:06
# 105 of 600, min objf=0.655714, max objf=0.963909, time remaining: 00:06:03
# 108 of 600, min objf=0.655714, max objf=0.963909, time remaining: 00:06:02
# 111 of 600, min objf=0.655714, max objf=0.963909, time remaining: 00:06:00
# 114 of 600, min objf=0.655714, max objf=0.963909, time remaining: 00:05:58
# 117 of 600, min objf=0.655714, max objf=0.963909, time remaining: 00:05:55
# 120 of 600, min objf=0.655714, max objf=0.963909, time remaining: 00:05:53
# 123 of 600, min objf=0.655714, max objf=0.963909, time remaining: 00:05:51
# 126 of 600, min objf=0.655714, max objf=0.963909, time remaining: 00:05:49
# 129 of 600, min objf=0.655714, max objf=0.963909, time remaining: 00:05:47
# 132 of 600, min objf=0.655714, max objf=0.963909, time remaining: 00:05:44
# 135 of 600, min objf=0.655714, max objf=0.963909, time remaining: 00:05:42
# 138 of 600, min objf=0.655714, max objf=1.04108, time remaining: 00:05:39
# 141 of 600, min objf=0.655714, max objf=1.04108, time remaining: 00:05:38
# 144 of 600, min objf=0.655714, max objf=1.04108, time remaining: 00:05:35
# 147 of 600, min objf=0.655714, max objf=1.04108, time remaining: 00:05:33
# 150 of 600, min objf=0.655714, max objf=1.04108, time remaining: 00:05:31
# 153 of 600, min objf=0.655714, max objf=1.04108, time remaining: 00:05:29
# 156 of 600, min objf=0.655714, max objf=1.04108, time remaining: 00:05:27
# 159 of 600, min objf=0.655714, max objf=1.04108, time remaining: 00:05:25
# 162 of 600, min objf=0.655714, max objf=1.04108, time remaining: 00:05:23
# 165 of 600, min objf=0.655714, max objf=1.04108, time remaining: 00:05:20
# 168 of 600, min objf=0.655714, max objf=1.04108, time remaining: 00:05:18
# 171 of 600, min objf=0.655714, max objf=1.04108, time remaining: 00:05:15
# 174 of 600, min objf=0.655714, max objf=1.04108, time remaining: 00:05:13
# 177 of 600, min objf=0.655714, max objf=1.04108, time remaining: 00:05:11
# 180 of 600, min objf=0.655714, max objf=1.04108, time remaining: 00:05:09
# 183 of 600, min objf=0.655714, max objf=1.04108, time remaining: 00:05:07
# 186 of 600, min objf=0.655714, max objf=1.04108, time remaining: 00:05:05
# 189 of 600, min objf=0.655714, max objf=1.04108, time remaining: 00:05:03
# 192 of 600, min objf=0.655714, max objf=1.04108, time remaining: 00:05:00
# 195 of 600, min objf=0.655714, max objf=1.04108, time remaining: 00:04:58
# 198 of 600, min objf=0.655714, max objf=1.04108, time remaining: 00:04:56
# 201 of 600, min objf=0.655714, max objf=1.04108, time remaining: 00:04:54
# 204 of 600, min objf=0.655714, max objf=1.04108, time remaining: 00:04:52
# 207 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:04:49
# 210 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:04:47
# 213 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:04:45
# 216 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:04:43
# 219 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:04:41
# 222 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:04:38
# 225 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:04:36
# 228 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:04:34
# 231 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:04:32
# 234 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:04:30
# 237 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:04:28
# 240 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:04:25
# 243 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:04:23
# 246 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:04:21
# 249 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:04:19
# 252 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:04:16
# 255 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:04:14
# 258 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:04:12
# 261 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:04:10
# 264 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:04:08
# 267 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:04:05
# 270 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:04:03
# 273 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:04:01
# 276 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:03:59
# 279 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:03:56
# 282 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:03:54
# 285 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:03:52
# 288 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:03:50
# 291 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:03:48
# 294 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:03:45
# 297 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:03:43
# 300 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:03:41
# 303 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:03:39
# 306 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:03:37
# 309 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:03:34
# 312 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:03:32
# 315 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:03:30
# 318 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:03:28
# 321 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:03:26
# 324 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:03:23
# 327 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:03:21
# 330 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:03:19
# 333 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:03:17
# 336 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:03:14
# 339 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:03:12
# 342 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:03:10
# 345 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:03:08
# 348 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:03:05
# 351 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:03:03
# 354 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:03:01
# 357 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:02:59
# 360 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:02:56
# 363 of 600, min objf=0.645424, max objf=1.04108, time remaining: 00:02:54
# 366 of 600, min objf=0.645424, max objf=1.04379, time remaining: 00:02:52
# 369 of 600, min objf=0.645424, max objf=1.04379, time remaining: 00:02:50
# 372 of 600, min objf=0.645424, max objf=1.04379, time remaining: 00:02:47
# 375 of 600, min objf=0.645424, max objf=1.04379, time remaining: 00:02:45
# 378 of 600, min objf=0.645424, max objf=1.04379, time remaining: 00:02:43
# 381 of 600, min objf=0.645424, max objf=1.04379, time remaining: 00:02:41
# 384 of 600, min objf=0.645424, max objf=1.04379, time remaining: 00:02:39
# 387 of 600, min objf=0.645424, max objf=1.04379, time remaining: 00:02:36
# 390 of 600, min objf=0.645424, max objf=1.04379, time remaining: 00:02:34
# 393 of 600, min objf=0.645424, max objf=1.04379, time remaining: 00:02:32
# 396 of 600, min objf=0.645424, max objf=1.04379, time remaining: 00:02:30
# 399 of 600, min objf=0.645424, max objf=1.04379, time remaining: 00:02:28
# 402 of 600, min objf=0.645424, max objf=1.04379, time remaining: 00:02:25
# 405 of 600, min objf=0.645424, max objf=1.04379, time remaining: 00:02:23
# 408 of 600, min objf=0.645424, max objf=1.04379, time remaining: 00:02:21
# 411 of 600, min objf=0.645424, max objf=1.04379, time remaining: 00:02:19
# 414 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:02:17
# 417 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:02:15
# 420 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:02:12
# 423 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:02:10
# 426 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:02:08
# 429 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:02:06
# 432 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:02:03
# 435 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:02:01
# 438 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:01:59
# 441 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:01:57
# 444 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:01:55
# 447 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:01:52
# 450 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:01:50
# 453 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:01:48
# 457 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:01:45
# 460 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:01:43
# 463 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:01:41
# 466 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:01:38
# 469 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:01:36
# 472 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:01:34
# 475 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:01:32
# 478 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:01:29
# 481 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:01:27
# 484 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:01:25
# 487 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:01:23
# 490 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:01:21
# 493 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:01:18
# 496 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:01:16
# 499 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:01:14
# 502 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:01:12
# 505 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:01:09
# 508 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:01:07
# 511 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:01:05
# 514 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:01:03
# 517 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:01:01
# 520 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:00:58
# 523 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:00:56
# 526 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:00:54
# 529 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:00:52
# 532 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:00:50
# 535 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:00:47
# 538 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:00:45
# 541 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:00:43
# 544 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:00:41
# 547 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:00:39
# 550 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:00:36
# 553 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:00:34
# 556 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:00:32
# 559 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:00:30
# 562 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:00:27
# 565 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:00:25
# 568 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:00:23
# 571 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:00:21
# 574 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:00:19
# 577 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:00:16
# 580 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:00:14
# 583 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:00:12
# 586 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:00:10
# 589 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:00:07
# 592 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:00:05
# 595 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:00:03
# 598 of 600, min objf=0.645424, max objf=1.07434, time remaining: 00:00:01
#
# *** Final SPOTPY summary ***
# Total Duration: 448.55 seconds
# Total Repetitions: 600
# Minimal objective value: 0.645424
# Corresponding parameter setting:
# FFf: 0.752215
# alpha: 0.221971
# beta: 0.473951
# QQf: 0.98473
# gamma: 0.934965
# k: 4.77153
# Maximal objective value: 1.07434
# Corresponding parameter setting:
# FFf: 0.97953
# alpha: 0.974943
# beta: 0.280803
# QQf: 0.915748
# gamma: 0.614086
# k: 4.15374
# ******************************
#
# Initializing the  Monte Carlo (MC) sampler  with  600  repetitions
# Starting the MC algorithm with 600 repetitions...
# Initialize database...
# ['csv', 'hdf5', 'ram', 'sql', 'custom', 'noData']
# * Database file '..\results\reservoirs\LISFLOOD\calibration\MC\6_parameters/012_samples.csv' created.
# 3 of 600, min objf=0.326404, max objf=0.356202, time remaining: 00:05:47
# 6 of 600, min objf=0.313447, max objf=0.358483, time remaining: 00:06:42
# 9 of 600, min objf=0.313447, max objf=0.358483, time remaining: 00:07:04
# 12 of 600, min objf=0.313447, max objf=0.378827, time remaining: 00:07:15
# 15 of 600, min objf=0.311126, max objf=0.378827, time remaining: 00:07:19
# 18 of 600, min objf=0.311126, max objf=0.378827, time remaining: 00:07:23
# 21 of 600, min objf=0.311126, max objf=0.404652, time remaining: 00:07:23
# 24 of 600, min objf=0.311126, max objf=0.404652, time remaining: 00:07:23
# 27 of 600, min objf=0.311126, max objf=0.433791, time remaining: 00:07:23
# 30 of 600, min objf=0.311126, max objf=0.472386, time remaining: 00:07:19
# 33 of 600, min objf=0.311126, max objf=0.472386, time remaining: 00:07:18
# 36 of 600, min objf=0.311126, max objf=0.472386, time remaining: 00:07:17
# 39 of 600, min objf=0.311126, max objf=0.472386, time remaining: 00:07:15
# 42 of 600, min objf=0.311126, max objf=0.472386, time remaining: 00:07:13
# 45 of 600, min objf=0.311126, max objf=0.472386, time remaining: 00:07:11
# 48 of 600, min objf=0.311126, max objf=0.472386, time remaining: 00:07:09
# 51 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:07:09
# 54 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:07:07
# 57 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:07:04
# 60 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:07:01
# 63 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:06:57
# 66 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:06:53
# 69 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:06:51
# 72 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:06:48
# 75 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:06:46
# 78 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:06:43
# 81 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:06:41
# 84 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:06:39
# 87 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:06:36
# 90 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:06:32
# 93 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:06:30
# 96 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:06:28
# 99 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:06:26
# 102 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:06:24
# 105 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:06:22
# 108 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:06:19
# 111 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:06:16
# 114 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:06:14
# 117 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:06:12
# 120 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:06:09
# 123 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:06:06
# 126 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:06:03
# 129 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:06:01
# 132 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:05:58
# 135 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:05:56
# 138 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:05:54
# 141 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:05:52
# 144 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:05:49
# 147 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:05:47
# 150 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:05:45
# 153 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:05:43
# 156 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:05:40
# 159 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:05:38
# 162 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:05:36
# 165 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:05:33
# 168 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:05:30
# 171 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:05:28
# 174 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:05:26
# 177 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:05:24
# 180 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:05:21
# 183 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:05:19
# 186 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:05:17
# 189 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:05:14
# 192 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:05:12
# 195 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:05:10
# 198 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:05:07
# 201 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:05:05
# 204 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:05:02
# 207 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:05:00
# 210 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:04:58
# 213 of 600, min objf=0.310645, max objf=0.472386, time remaining: 00:04:55
# 216 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:04:53
# 219 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:04:50
# 222 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:04:48
# 225 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:04:46
# 228 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:04:43
# 231 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:04:41
# 234 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:04:38
# 237 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:04:36
# 240 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:04:34
# 243 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:04:32
# 246 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:04:29
# 249 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:04:27
# 252 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:04:25
# 255 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:04:22
# 258 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:04:20
# 261 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:04:17
# 264 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:04:15
# 267 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:04:13
# 270 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:04:11
# 273 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:04:09
# 276 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:04:06
# 279 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:04:04
# 282 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:04:01
# 285 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:03:59
# 288 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:03:57
# 291 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:03:54
# 294 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:03:52
# 297 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:03:50
# 300 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:03:47
# 303 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:03:45
# 306 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:03:43
# 309 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:03:40
# 312 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:03:38
# 315 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:03:36
# 318 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:03:33
# 321 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:03:31
# 324 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:03:29
# 327 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:03:27
# 330 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:03:24
# 333 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:03:22
# 336 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:03:20
# 339 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:03:17
# 342 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:03:15
# 345 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:03:13
# 348 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:03:10
# 351 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:03:08
# 354 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:03:06
# 357 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:03:03
# 360 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:03:01
# 363 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:02:59
# 366 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:02:57
# 369 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:02:54
# 372 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:02:52
# 375 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:02:50
# 378 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:02:47
# 381 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:02:45
# 384 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:02:43
# 387 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:02:41
# 390 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:02:38
# 393 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:02:36
# 396 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:02:34
# 399 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:02:31
# 402 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:02:29
# 405 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:02:27
# 408 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:02:25
# 411 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:02:22
# 414 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:02:20
# 417 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:02:18
# 420 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:02:15
# 423 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:02:13
# 426 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:02:11
# 429 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:02:09
# 432 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:02:06
# 435 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:02:04
# 438 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:02:02
# 441 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:02:00
# 444 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:01:57
# 447 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:01:55
# 450 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:01:53
# 453 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:01:51
# 456 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:01:48
# 459 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:01:46
# 462 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:01:44
# 465 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:01:41
# 468 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:01:39
# 471 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:01:37
# 474 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:01:35
# 477 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:01:32
# 480 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:01:30
# 483 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:01:28
# 486 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:01:26
# 489 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:01:23
# 492 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:01:21
# 495 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:01:19
# 498 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:01:16
# 501 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:01:14
# 504 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:01:12
# 507 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:01:10
# 510 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:01:07
# 513 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:01:05
# 516 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:01:03
# 519 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:01:01
# 522 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:00:58
# 525 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:00:56
# 528 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:00:54
# 531 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:00:51
# 534 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:00:49
# 537 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:00:47
# 540 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:00:45
# 543 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:00:42
# 546 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:00:40
# 549 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:00:38
# 552 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:00:36
# 555 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:00:33
# 558 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:00:31
# 561 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:00:29
# 564 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:00:26
# 567 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:00:24
# 570 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:00:22
# 573 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:00:20
# 576 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:00:17
# 579 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:00:15
# 582 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:00:13
# 585 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:00:11
# 588 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:00:08
# 591 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:00:06
# 594 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:00:04
# 597 of 600, min objf=0.310645, max objf=0.508961, time remaining: 00:00:02
# 600 of 600, min objf=0.310645, max objf=0.519062, time remaining: 23:59:59
#
# *** Final SPOTPY summary ***
# Total Duration: 454.13 seconds
# Total Repetitions: 600
# Minimal objective value: 0.310645
# Corresponding parameter setting:
# FFf: 0.340263
# alpha: 0.946059
# beta: 0.451503
# QQf: 0.129227
# gamma: 0.40298
# k: 2.76148
# Maximal objective value: 0.519062
# Corresponding parameter setting:
# FFf: 0.444758
# alpha: 0.100804
# beta: 0.804458
# QQf: 0.977835
# gamma: 0.78287
# k: 1.24342
# ******************************
#
# Initializing the  Monte Carlo (MC) sampler  with  600  repetitions
# Starting the MC algorithm with 600 repetitions...
# Initialize database...
# ['csv', 'hdf5', 'ram', 'sql', 'custom', 'noData']
# * Database file '..\results\reservoirs\LISFLOOD\calibration\MC\6_parameters/014_samples.csv' created.
# 3 of 600, min objf=0.524625, max objf=0.821555, time remaining: 00:05:46
# 6 of 600, min objf=0.524625, max objf=0.821555, time remaining: 00:06:21
# 9 of 600, min objf=0.524625, max objf=0.821555, time remaining: 00:06:43
# 12 of 600, min objf=0.524625, max objf=0.821555, time remaining: 00:06:48
# 15 of 600, min objf=0.524625, max objf=0.821555, time remaining: 00:06:52
# 18 of 600, min objf=0.524625, max objf=0.821555, time remaining: 00:06:58
# 21 of 600, min objf=0.524625, max objf=0.821555, time remaining: 00:06:56
# 24 of 600, min objf=0.524625, max objf=0.821555, time remaining: 00:06:56
# 27 of 600, min objf=0.51742, max objf=0.821555, time remaining: 00:06:57
# 30 of 600, min objf=0.51742, max objf=0.821555, time remaining: 00:06:56
# 33 of 600, min objf=0.51742, max objf=1.02879, time remaining: 00:06:54
# 36 of 600, min objf=0.51742, max objf=1.02879, time remaining: 00:06:52
# 39 of 600, min objf=0.51742, max objf=1.02879, time remaining: 00:06:50
# 42 of 600, min objf=0.51742, max objf=1.02879, time remaining: 00:06:49
# 45 of 600, min objf=0.517372, max objf=1.02879, time remaining: 00:06:47
# 48 of 600, min objf=0.517372, max objf=1.02879, time remaining: 00:06:44
# 51 of 600, min objf=0.517372, max objf=1.02879, time remaining: 00:06:40
# 54 of 600, min objf=0.517372, max objf=1.02879, time remaining: 00:06:39
# 57 of 600, min objf=0.517372, max objf=1.02879, time remaining: 00:06:38
# 60 of 600, min objf=0.517372, max objf=1.02879, time remaining: 00:06:37
# 63 of 600, min objf=0.517372, max objf=1.02879, time remaining: 00:06:35
# 66 of 600, min objf=0.517372, max objf=1.02879, time remaining: 00:06:32
# 69 of 600, min objf=0.517372, max objf=1.02879, time remaining: 00:06:30
# 72 of 600, min objf=0.517372, max objf=1.02879, time remaining: 00:06:28
# 75 of 600, min objf=0.514643, max objf=1.02879, time remaining: 00:06:27
# 78 of 600, min objf=0.514643, max objf=1.02879, time remaining: 00:06:27
# 81 of 600, min objf=0.513067, max objf=1.02879, time remaining: 00:06:26
# 84 of 600, min objf=0.513067, max objf=1.02879, time remaining: 00:06:25
# 87 of 600, min objf=0.513067, max objf=1.02879, time remaining: 00:06:23
# 90 of 600, min objf=0.513067, max objf=1.02879, time remaining: 00:06:21
# 93 of 600, min objf=0.513067, max objf=1.02879, time remaining: 00:06:20
# 96 of 600, min objf=0.513067, max objf=1.02879, time remaining: 00:06:18
# 99 of 600, min objf=0.513067, max objf=1.02879, time remaining: 00:06:17
# 102 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:06:16
# 105 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:06:14
# 108 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:06:11
# 111 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:06:09
# 114 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:06:08
# 117 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:06:06
# 120 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:06:04
# 123 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:06:02
# 126 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:06:00
# 129 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:05:58
# 132 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:05:56
# 135 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:05:54
# 138 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:05:52
# 141 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:05:50
# 144 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:05:49
# 147 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:05:46
# 150 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:05:45
# 153 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:05:43
# 156 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:05:41
# 159 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:05:39
# 162 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:05:37
# 165 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:05:35
# 168 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:05:33
# 171 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:05:31
# 174 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:05:30
# 177 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:05:27
# 180 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:05:25
# 183 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:05:23
# 186 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:05:21
# 189 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:05:18
# 192 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:05:16
# 195 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:05:14
# 198 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:05:12
# 201 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:05:09
# 204 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:05:07
# 207 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:05:05
# 210 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:05:03
# 213 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:05:01
# 216 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:04:58
# 219 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:04:56
# 222 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:04:54
# 225 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:04:51
# 228 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:04:49
# 231 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:04:47
# 234 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:04:45
# 237 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:04:43
# 240 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:04:41
# 243 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:04:38
# 246 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:04:36
# 249 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:04:33
# 252 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:04:31
# 255 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:04:28
# 258 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:04:26
# 261 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:04:23
# 264 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:04:21
# 267 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:04:19
# 270 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:04:16
# 273 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:04:13
# 276 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:04:11
# 279 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:04:09
# 282 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:04:06
# 285 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:04:04
# 288 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:04:01
# 291 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:03:59
# 294 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:03:56
# 297 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:03:54
# 300 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:03:52
# 303 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:03:49
# 306 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:03:47
# 309 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:03:44
# 312 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:03:42
# 315 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:03:40
# 318 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:03:37
# 321 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:03:35
# 324 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:03:33
# 327 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:03:31
# 330 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:03:28
# 333 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:03:26
# 336 of 600, min objf=0.513067, max objf=1.096, time remaining: 00:03:24
# 339 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:03:21
# 342 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:03:19
# 345 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:03:17
# 348 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:03:14
# 351 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:03:12
# 354 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:03:09
# 357 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:03:07
# 360 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:03:05
# 363 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:03:03
# 366 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:03:01
# 369 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:02:58
# 372 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:02:56
# 375 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:02:54
# 378 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:02:51
# 381 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:02:49
# 384 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:02:47
# 387 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:02:44
# 390 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:02:42
# 393 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:02:39
# 396 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:02:37
# 399 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:02:35
# 402 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:02:32
# 405 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:02:30
# 408 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:02:28
# 411 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:02:26
# 414 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:02:23
# 417 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:02:21
# 420 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:02:18
# 423 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:02:16
# 426 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:02:14
# 429 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:02:11
# 432 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:02:09
# 435 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:02:07
# 438 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:02:04
# 441 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:02:02
# 444 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:02:00
# 447 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:01:57
# 450 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:01:55
# 453 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:01:53
# 456 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:01:50
# 459 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:01:48
# 462 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:01:46
# 465 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:01:43
# 468 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:01:41
# 471 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:01:39
# 474 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:01:36
# 477 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:01:34
# 480 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:01:32
# 483 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:01:29
# 486 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:01:27
# 489 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:01:25
# 492 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:01:22
# 495 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:01:20
# 498 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:01:18
# 501 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:01:15
# 504 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:01:13
# 507 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:01:11
# 510 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:01:09
# 513 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:01:06
# 516 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:01:04
# 519 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:01:02
# 522 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:00:59
# 525 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:00:57
# 528 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:00:55
# 531 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:00:52
# 534 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:00:50
# 537 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:00:48
# 540 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:00:45
# 543 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:00:43
# 546 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:00:41
# 549 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:00:38
# 552 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:00:36
# 555 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:00:34
# 558 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:00:32
# 561 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:00:29
# 564 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:00:27
# 567 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:00:25
# 570 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:00:22
# 573 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:00:20
# 576 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:00:18
# 579 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:00:15
# 582 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:00:13
# 585 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:00:11
# 588 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:00:08
# 591 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:00:06
# 594 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:00:04
# 597 of 600, min objf=0.513067, max objf=1.11727, time remaining: 00:00:02
# 600 of 600, min objf=0.513067, max objf=1.11727, time remaining: 23:59:59
#
# *** Final SPOTPY summary ***
# Total Duration: 460.96 seconds
# Total Repetitions: 600
# Minimal objective value: 0.513067
# Corresponding parameter setting:
# FFf: 0.506968
# alpha: 0.964103
# beta: 0.950628
# QQf: 0.10605
# gamma: 0.641882
# k: 3.35272
# Maximal objective value: 1.11727
# Corresponding parameter setting:
# FFf: 0.219329
# alpha: 0.00500576
# beta: 0.447306
# QQf: 0.964113
# gamma: 0.963075
# k: 1.77292
# ******************************
#
# Initializing the  Monte Carlo (MC) sampler  with  600  repetitions
# Starting the MC algorithm with 600 repetitions...
# Initialize database...
# ['csv', 'hdf5', 'ram', 'sql', 'custom', 'noData']
# * Database file '..\results\reservoirs\LISFLOOD\calibration\MC\6_parameters/016_samples.csv' created.
# 3 of 600, min objf=0.776948, max objf=1.39487, time remaining: 00:05:53
# 6 of 600, min objf=0.730203, max objf=1.39487, time remaining: 00:06:15
# 9 of 600, min objf=0.7156, max objf=1.39487, time remaining: 00:06:24
# 12 of 600, min objf=0.711566, max objf=1.39487, time remaining: 00:06:35
# 15 of 600, min objf=0.711566, max objf=1.39563, time remaining: 00:06:43
# 18 of 600, min objf=0.711566, max objf=1.39563, time remaining: 00:06:49
# 21 of 600, min objf=0.711566, max objf=1.39563, time remaining: 00:06:53
# 24 of 600, min objf=0.711566, max objf=1.39563, time remaining: 00:06:50
# 27 of 600, min objf=0.711566, max objf=1.49293, time remaining: 00:06:48
# 30 of 600, min objf=0.711566, max objf=1.49293, time remaining: 00:06:48
# 33 of 600, min objf=0.711566, max objf=1.49293, time remaining: 00:06:48
# 36 of 600, min objf=0.711566, max objf=1.49293, time remaining: 00:06:46
# 39 of 600, min objf=0.711566, max objf=1.49293, time remaining: 00:06:42
# 42 of 600, min objf=0.711566, max objf=1.49293, time remaining: 00:06:42
# 45 of 600, min objf=0.711566, max objf=1.49293, time remaining: 00:06:40
# 48 of 600, min objf=0.711566, max objf=1.49293, time remaining: 00:06:39
# ...
# 597 of 600, min objf=0.583847, max objf=13.4743, time remaining: 00:00:02
# 600 of 600, min objf=0.583847, max objf=13.4743, time remaining: 23:59:59
#
# *** Final SPOTPY summary ***
# Total Duration: 468.27 seconds
# Total Repetitions: 600
# Minimal objective value: 0.583847
# Corresponding parameter setting:
# FFf: 0.94512
# alpha: 0.561265
# beta: 0.378344
# QQf: 0.933541
# gamma: 0.378936
# k: 4.25407
# Maximal objective value: 13.4743
# Corresponding parameter setting:
# FFf: 0.201661
# alpha: 0.192298
# beta: 0.172861
# QQf: 0.965685
# gamma: 0.577586
# k: 2.49776
# ******************************
#
# Initializing the  Monte Carlo (MC) sampler  with  600  repetitions
# Starting the MC algorithm with 600 repetitions...
# Initialize database...
# ['csv', 'hdf5', 'ram', 'sql', 'custom', 'noData']
# * Database file '..\results\reservoirs\LISFLOOD\calibration\MC\6_parameters/638_samples.csv' created.
# 3 of 600, min objf=1.44761, max objf=4.00389, time remaining: 00:05:27
# 6 of 600, min objf=1.44761, max objf=12.0824, time remaining: 00:06:26
# 9 of 600, min objf=1.44761, max objf=12.0824, time remaining: 00:06:32
# 12 of 600, min objf=1.15557, max objf=12.8564, time remaining: 00:06:43
# 15 of 600, min objf=1.0483, max objf=12.8564, time remaining: 00:06:46
# 18 of 600, min objf=1.0483, max objf=12.8564, time remaining: 00:06:52
# 21 of 600, min objf=1.0483, max objf=12.8564, time remaining: 00:06:53
# 24 of 600, min objf=1.0483, max objf=12.8564, time remaining: 00:06:57
# 27 of 600, min objf=1.0483, max objf=13.5316, time remaining: 00:06:55
# 30 of 600, min objf=1.00159, max objf=13.5316, time remaining: 00:06:51
# 33 of 600, min objf=1.00159, max objf=13.5316, time remaining: 00:06:47
# 36 of 600, min objf=1.00159, max objf=13.5316, time remaining: 00:06:47
# 39 of 600, min objf=1.00159, max objf=13.5316, time remaining: 00:06:44
# 42 of 600, min objf=1.00159, max objf=13.5316, time remaining: 00:06:44
# 45 of 600, min objf=1.00159, max objf=13.5316, time remaining: 00:06:40
# 48 of 600, min objf=1.00159, max objf=13.5316, time remaining: 00:06:38
# 51 of 600, min objf=1.00159, max objf=13.5316, time remaining: 00:06:37
# 54 of 600, min objf=1.00159, max objf=13.5316, time remaining: 00:06:37
# 57 of 600, min objf=1.00159, max objf=13.5316, time remaining: 00:06:36
# 60 of 600, min objf=1.00159, max objf=13.5316, time remaining: 00:06:33
# 63 of 600, min objf=0.975336, max objf=13.5316, time remaining: 00:06:31
# 66 of 600, min objf=0.975336, max objf=13.5316, time remaining: 00:06:27
# 69 of 600, min objf=0.975336, max objf=13.5316, time remaining: 00:06:26
# 72 of 600, min objf=0.975336, max objf=13.5316, time remaining: 00:06:24
# 75 of 600, min objf=0.975336, max objf=13.5316, time remaining: 00:06:23
# 78 of 600, min objf=0.960043, max objf=13.5316, time remaining: 00:06:20
# 81 of 600, min objf=0.960043, max objf=13.5316, time remaining: 00:06:17
# 84 of 600, min objf=0.960043, max objf=13.5316, time remaining: 00:06:15
# 87 of 600, min objf=0.960043, max objf=13.5316, time remaining: 00:06:14
# 90 of 600, min objf=0.957181, max objf=13.5316, time remaining: 00:06:11
# 93 of 600, min objf=0.957181, max objf=13.5316, time remaining: 00:06:08
# 96 of 600, min objf=0.957181, max objf=13.5316, time remaining: 00:06:07
# 99 of 600, min objf=0.957181, max objf=13.5316, time remaining: 00:06:06
# 102 of 600, min objf=0.936805, max objf=13.5316, time remaining: 00:06:03
# 105 of 600, min objf=0.936805, max objf=13.5316, time remaining: 00:06:01
# 108 of 600, min objf=0.936805, max objf=13.5316, time remaining: 00:05:59
# 111 of 600, min objf=0.936805, max objf=13.5316, time remaining: 00:06:09
# 114 of 600, min objf=0.936805, max objf=13.5316, time remaining: 00:06:06
# 117 of 600, min objf=0.936805, max objf=13.5316, time remaining: 00:06:04
# 120 of 600, min objf=0.936805, max objf=13.5316, time remaining: 00:06:01
# 123 of 600, min objf=0.936805, max objf=13.5316, time remaining: 00:05:59
# 126 of 600, min objf=0.936805, max objf=13.5316, time remaining: 00:05:57
# 129 of 600, min objf=0.936805, max objf=13.5316, time remaining: 00:05:55
# 132 of 600, min objf=0.936805, max objf=13.5316, time remaining: 00:05:52
# 135 of 600, min objf=0.936805, max objf=13.6563, time remaining: 00:05:50
# 138 of 600, min objf=0.936805, max objf=13.6563, time remaining: 00:05:48
# 141 of 600, min objf=0.936805, max objf=13.6563, time remaining: 00:05:46
# 144 of 600, min objf=0.936805, max objf=13.6563, time remaining: 00:05:44
# 147 of 600, min objf=0.936805, max objf=13.6563, time remaining: 00:05:41
# 150 of 600, min objf=0.936805, max objf=13.6563, time remaining: 00:05:39
# 153 of 600, min objf=0.936805, max objf=13.6563, time remaining: 00:05:37
# 156 of 600, min objf=0.936805, max objf=13.6563, time remaining: 00:05:34
# 159 of 600, min objf=0.936805, max objf=13.6563, time remaining: 00:05:32
# 162 of 600, min objf=0.936805, max objf=13.6563, time remaining: 00:05:30
# 165 of 600, min objf=0.936805, max objf=13.6563, time remaining: 00:05:27
# 168 of 600, min objf=0.936805, max objf=13.6563, time remaining: 00:05:26
# 171 of 600, min objf=0.936805, max objf=13.6563, time remaining: 00:05:23
# 174 of 600, min objf=0.936805, max objf=13.6563, time remaining: 00:05:21
# 177 of 600, min objf=0.936805, max objf=13.6563, time remaining: 00:05:18
# 180 of 600, min objf=0.936805, max objf=13.6563, time remaining: 00:05:16
# 183 of 600, min objf=0.936805, max objf=13.6563, time remaining: 00:05:14
# 186 of 600, min objf=0.936805, max objf=13.6563, time remaining: 00:05:11
# 189 of 600, min objf=0.936805, max objf=13.6563, time remaining: 00:05:09
# 192 of 600, min objf=0.936805, max objf=13.6563, time remaining: 00:05:06
# 195 of 600, min objf=0.936805, max objf=13.6563, time remaining: 00:05:04
# 198 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:05:02
# 201 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:05:00
# 204 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:04:58
# 207 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:04:55
# 210 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:04:53
# 213 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:04:51
# 216 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:04:48
# 219 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:04:46
# 222 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:04:45
# 225 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:04:43
# 228 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:04:40
# 231 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:04:38
# 234 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:04:36
# 237 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:04:33
# 240 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:04:31
# 243 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:04:29
# 246 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:04:27
# 249 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:04:24
# 252 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:04:22
# 255 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:04:20
# 258 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:04:17
# 261 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:04:15
# 264 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:04:13
# 267 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:04:11
# 270 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:04:09
# 273 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:04:06
# 276 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:04:04
# 279 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:04:02
# 282 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:03:59
# 285 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:03:57
# 288 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:03:55
# 291 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:03:53
# 294 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:03:50
# 297 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:03:48
# 300 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:03:46
# 303 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:03:44
# 306 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:03:41
# 309 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:03:39
# 312 of 600, min objf=0.936805, max objf=13.6826, time remaining: 00:03:37
# 315 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:03:35
# 318 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:03:32
# 321 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:03:30
# 324 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:03:28
# 327 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:03:25
# 330 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:03:23
# 333 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:03:21
# 336 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:03:18
# 339 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:03:16
# 342 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:03:14
# 345 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:03:12
# 348 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:03:09
# 351 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:03:07
# 354 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:03:05
# 357 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:03:03
# 360 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:03:00
# 363 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:02:58
# 366 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:02:56
# 369 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:02:54
# 372 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:02:52
# 375 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:02:50
# 378 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:02:47
# 381 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:02:45
# 384 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:02:43
# 387 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:02:40
# 390 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:02:38
# 393 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:02:36
# 396 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:02:34
# 399 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:02:31
# 402 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:02:29
# 405 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:02:27
# 408 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:02:25
# 411 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:02:22
# 414 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:02:20
# 417 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:02:18
# 420 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:02:15
# 423 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:02:13
# 426 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:02:11
# 429 of 600, min objf=0.917152, max objf=13.6826, time remaining: 00:02:09
# 432 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:02:06
# 435 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:02:04
# 438 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:02:02
# 441 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:02:00
# 444 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:01:57
# 447 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:01:55
# 450 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:01:53
# 453 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:01:51
# 456 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:01:48
# 459 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:01:46
# 462 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:01:44
# 465 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:01:42
# 468 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:01:39
# 471 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:01:37
# 474 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:01:35
# 477 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:01:33
# 480 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:01:30
# 483 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:01:28
# 486 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:01:26
# 489 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:01:24
# 492 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:01:21
# 495 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:01:19
# 498 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:01:17
# 501 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:01:15
# 504 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:01:12
# 507 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:01:10
# 510 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:01:08
# 513 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:01:06
# 516 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:01:03
# 519 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:01:01
# 522 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:00:59
# 525 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:00:57
# 528 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:00:54
# 531 of 600, min objf=0.917152, max objf=13.734, time remaining: 00:00:52
# 534 of 600, min objf=0.905665, max objf=13.734, time remaining: 00:00:50
# 537 of 600, min objf=0.905665, max objf=13.734, time remaining: 00:00:48
# 540 of 600, min objf=0.905665, max objf=13.734, time remaining: 00:00:45
# 543 of 600, min objf=0.905665, max objf=13.734, time remaining: 00:00:43
# 546 of 600, min objf=0.905665, max objf=13.734, time remaining: 00:00:41
# 549 of 600, min objf=0.905665, max objf=13.734, time remaining: 00:00:38
# 552 of 600, min objf=0.905665, max objf=13.734, time remaining: 00:00:36
# 555 of 600, min objf=0.905665, max objf=13.734, time remaining: 00:00:34
# 558 of 600, min objf=0.905665, max objf=13.734, time remaining: 00:00:32
# 561 of 600, min objf=0.905665, max objf=13.734, time remaining: 00:00:29
# 564 of 600, min objf=0.905665, max objf=13.734, time remaining: 00:00:27
# 567 of 600, min objf=0.905665, max objf=13.734, time remaining: 00:00:25
# 570 of 600, min objf=0.905665, max objf=13.734, time remaining: 00:00:22
# 573 of 600, min objf=0.905665, max objf=13.734, time remaining: 00:00:20
# 576 of 600, min objf=0.905665, max objf=13.734, time remaining: 00:00:18
# 579 of 600, min objf=0.905665, max objf=13.734, time remaining: 00:00:15
# 582 of 600, min objf=0.905665, max objf=13.734, time remaining: 00:00:13
# 585 of 600, min objf=0.905665, max objf=13.9057, time remaining: 00:00:11
# 588 of 600, min objf=0.905665, max objf=13.9057, time remaining: 00:00:09
# 591 of 600, min objf=0.905665, max objf=13.9057, time remaining: 00:00:06
# 594 of 600, min objf=0.905665, max objf=13.9057, time remaining: 00:00:04
# 597 of 600, min objf=0.905665, max objf=13.9057, time remaining: 00:00:02
# 600 of 600, min objf=0.905665, max objf=13.9057, time remaining: 23:59:59
#
# *** Final SPOTPY summary ***
# Total Duration: 464.27 seconds
# Total Repetitions: 600
# Minimal objective value: 0.905665
# Corresponding parameter setting:
# FFf: 0.839387
# alpha: 0.690523
# beta: 0.0914832
# QQf: 0.898245
# gamma: 0.633161
# k: 1.48519
# Maximal objective value: 13.9057
# Corresponding parameter setting:
# FFf: 0.202836
# alpha: 0.289248
# beta: 0.368665
# QQf: 0.936773
# gamma: 0.719986
# k: 3.42976
# ******************************

# %% [markdown]
# ## Analyse results

# %%
for ResID in [12]:#tqdm(reservoirs.index):
    
    try:

# %%
ResID = 481 #507

# %%
        # file where the calibration results will be saved
        dbname = f'{path_out}/{ResID:03}_samples'

        # read CSV of results
        results = pd.read_csv(f'{dbname}.csv')
        results.index.name = 'iteration'
        parcols = [col for col in results.columns if col.startswith('par')]

        # compute the Pareto front and the best iteration
        front = pareto_front(results.like1, results.like2)
        best_iter = front.pow(2).sum(axis=1).pow(.5).idxmin()

# %%
        # select and export optimal parameters
        parvalues = {col[3:]: float(results.loc[best_iter, col]) for col in parcols}
        with open(f'{path_out}/{ResID:03}_optimal_parameters.yml', 'w') as file:
            yaml.dump(parvalues, file)

# %%
    fig, ax = plt.subplots(figsize=(4, 4))
    ax.scatter(results.like1, results.like2, s=1, c='gray', label='iteration', alpha=.2)
    ax.scatter(*front.loc[best_iter, ['like1', 'like2']], c='steelblue', label='optimum', s=4)
    ax.plot(front.like1, front.like2, c='k', lw=1, ls=':', label='pareto front', zorder=0)
    # vmax = np.ceil(front[['like1', 'like2']].max().max() / .2) * .2 + .025
    vmax = None
    # # ticks = np.arange(0, vmax, .25)
    ax.set(xlim=(-.025, vmax),
           xlabel=r'$L_{outflow}$',
           # xticks=ticks,
           ylim=(-.025, vmax),
           ylabel=r'$L_{storage}$',
           # yticks=ax.get_xticks(),
          )
    ax.set_title(ResID)
    fig.legend(frameon=False, loc=1, bbox_to_anchor=[1.175, .7, .1, .2]);
    plt.savefig(path_out / f'{ResID:03}_pareto_front.jpg', dpi=300, bbox_inches='tight');

# %%
# observed time series
obs = resops_ts[ResID][['storage', 'inflow', 'outflow']].copy()
obs[obs < 0] = np.nan
        
# define train and test time series
start_obs = max([obs[var].first_valid_index() for var in ['storage', 'outflow']])
end_obs = min([obs[var].last_valid_index() for var in ['storage', 'outflow']])
cal_days = timedelta(days=np.floor((end_obs - start_obs).days * train_size))
start_cal = end_obs - cal_days

# define train and test time series
x_train = glofas_ts[ResID].inflow[start_cal:end_obs]
y_train = obs.loc[start_cal:end_obs, ['storage', 'outflow']]
x_test = glofas_ts[ResID].inflow[start:start_cal]
y_test = obs.loc[start:start_cal, ['storage', 'outflow']]

# %%
# extract GloFAS reservoir parameters
Vc, Vtot, Qmin = reservoirs.loc[ResID, ['clim', 'CAP', 'minq']]
Vtot *= 1e6
Vc *= Vtot

# initialize the calibration setup of the LISFLOOD reservoir routine
setup = bivariate_6pars(x_train, y_train.storage, y_train.outflow,
                        Vc, Vtot, Qmin,
                        KGEmod)

# %%
results[['KGE1', 'KGE2']] = np.nan
# idx = results[results.like2.isnull()].index[1]
for idx in tqdm(results.index):
    
    parvalues = {col[3:]: float(results.loc[idx, col]) for col in parcols}

    # declare the reservoir with the optimal parameters
    Vn, Vf = [parvalues[var] * Vtot for var in ['FFn', 'FFf']]
    Vn_adj = Vn + parvalues['alpha'] * (Vf - Vn)
    Qn, Qf = [setup.inflow.quantile(parvalues[var]) for var in ['QQn', 'QQf']]
    k = parvalues['k']
    res = Lisflood(Vc, Vn, Vn_adj, Vf, Vtot, Qmin, Qn, Qf)

    # simulate the whole period and analyse
    sim = res.simulate(x_train, y_train.storage[start_cal], k=k)

    results.loc[idx, 'KGE1'] = 1 - KGEmod(y_train.outflow, sim.outflow)[0]
    results.loc[idx, 'KGE2'] = 1 - KGEmod(y_train.storage, sim.storage)[0]

# %%
results[['KGE1', 'KGE2']].describe()

# %%
fig, ax = plt.subplots(figsize=(4, 4))
ax.scatter(results.KGE1, results.KGE2, s=1, c='gray', label='iteration', alpha=.2)
# vmax = np.ceil(front[['like1', 'like2']].max().max() / .2) * .2 + .025
# vmax = None
# ticks = np.arange(0, vmax, .25)
ax.set(xlim=(-.025, None),
       xlabel=r'$KGE_{outflow}$',
       # xticks=ticks,
       ylim=(-.025, None),
       ylabel=r'$KGE_{storage}$',
       # yticks=ax.get_xticks(),
      )
ax.set_title(ResID)
fig.legend(frameon=False, loc=1, bbox_to_anchor=[1.175, .7, .1, .2]);

# %%
fig, axes = plt.subplots(ncols=2, figsize=(8, 4))

for i, (ax, var) in enumerate(zip(axes, ['outflow', 'storage']), start=1):
    ax.scatter(results[f'KGE{i}'], results[f'like{i}'], s=1, c='gray', label='iteration', alpha=.2)
    ax.set(title=var,
           xlabel='KGE',
           # xlim=(None, 1.02),
           # ylim=(-.02, None),
          )
    if ax == axes[0]:
        ax.set_ylabel('likelihood')
    
# axes[0].axhline(1, ls=':', c='k', lw=.5)
# axes[0].axvline(0, ls=':', c='k', lw=.5);

# %%
# compute the Pareto front and the best iteration
front = pareto_front(1 - results.KGE1, 1 - results.KGE2)
front['d'] = (1 - front[['KGE1', 'KGE2']]).pow(2).sum(axis=1).pow(.5)
best_iter = front.d.idxmin()

# %%
front

# %%
fig, ax = plt.subplots(figsize=(4, 4))
ax.scatter(1 - results.KGE1, 1 - results.KGE2, s=1, c='gray', label='iteration', alpha=.2)
ax.scatter(*front.loc[best_iter, ['KGE1', 'KGE2']], c='steelblue', label='optimum', s=4)
ax.scatter(*front.loc[best_iter, ['KGE1', 'KGE2']], c='steelblue', label='optimum', s=4)
# ax.plot(front.KGE1, front.KGE2, c='k', lw=1, ls=':', label='pareto front', zorder=0)
# vmax = np.ceil(front[['KGE1', 'KGE2']].max().max() / .2) * .2 + .025
# vmax = None
# # ticks = np.arange(0, vmax, .25)
ax.set(xlim=(-.025, None),
       xlabel=r'$L_{outflow}$',
       # xticks=ticks,
       ylim=(-.025, None),
       ylabel=r'$L_{storage}$',
       # yticks=ax.get_xticks(),
      )
ax.set_title(ResID)
fig.legend(frameon=False, loc=1, bbox_to_anchor=[1.175, .7, .1, .2]);
plt.savefig(path_out / f'{ResID:03}_pareto_front.jpg', dpi=300, bbox_inches='tight');

# %%
results.loc[results.like2.isnull(), parcols].iloc[0]

# %%
        # select and export optimal parameters
        parvalues = {col[3:]: float(results.loc[best_iter, col]) for col in parcols}
        with open(f'{path_out}/{ResID:03}_optimal_parameters.yml', 'w') as file:
            yaml.dump(parvalues, file)

        # declare the reservoir with the optimal parameters
        Vn, Vf = [parvalues[var] * Vtot for var in ['FFn', 'FFf']]
        Vn_adj = Vn + parvalues['alpha'] * (Vf - Vn)
        Qn, Qf = [setup.inflow.quantile(parvalues[var]) for var in ['QQn', 'QQf']]
        k = parvalues['k']
        res = Lisflood(Vc, Vn, Vn_adj, Vf, Vtot, Qmin, Qn, Qf)

        # define time series
        start_obs = max([resops_ts[ResID][var].first_valid_index() for var in ['storage', 'outflow']])
        x = glofas_ts[ResID][start_obs:]
        y = resops_ts[ResID][start_obs:]

        # simulate the whole period and analyse
        sim = res.simulate(x.inflow, y.storage[start_obs], k=k)
        res.scatter(sim, y, norm=False, title=ResID, save=path_out / f'{ResID:03}_scatter.jpg')
        res.lineplot({'GloFAS': x, 'cal': sim}, y, save=path_out / f'{ResID:03}_lineplot.jpg')

    except:
        print(f'ERROR. {ResID}')
        continue

# %% [markdown]
# ***

# %%
    # extract GloFAS reservoir parameters
    Vc, Vtot, Qmin = reservoirs.loc[ResID, ['clim', 'CAP', 'minq']]
    Vtot *= 1e6
    Vc *= Vtot

    # initialize the calibration setup of the LISFLOOD reservoir routine
    setup = bivariate_6pars(x, y.storage, y.outflow,
                            Vc, Vtot, Qmin,
                            KGEmod)

# %%
    simulations = {}
    front[['KGE1', 'KGE2']] = np.nan
    for i in tqdm(front.index):
        Q, S = setup.simulation(results.loc[i, parcols])
        simulations[i] = {'outflow': Q, 'storage': S}
        front.loc[i, 'KGE1'] = KGEmod(y.outflow, Q)[0]
        front.loc[i, 'KGE2'] = KGEmod(y.storage, S)[0]

# %%
    # plot simulations in the pareto front
    fig, axes = plt.subplots(nrows=2, figsize=(12, 6), sharex=True)
    for i, (ax, var, unit) in enumerate(zip(axes, ['outflow', 'storage'], ['m3/s', 'm3']), start=1):
        ax.plot(y[var], c='k', lw=.5, label='obs', zorder=2)
        ax.plot(simulations[best_iter][var], c='steelblue', lw=1, label='best iteration', zorder=3)
        for s, dct in simulations.items():
            ax.plot(dct[var], c='gray', lw=.5, alpha=.2, label='pareto front')
        ax.set(title='{0} KGE={1:.2f}'.format(var, front.loc[best_iter, f'KGE{i}']),
               ylabel=unit)
    ax.set(xlim=(start_cal, end))
    handles, labels = ax.get_legend_handles_labels()
    fig.legend(handles[:3], labels[:3], frameon=False, loc=8, ncol=3);
